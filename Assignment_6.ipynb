# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv')

# %%
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
plt.plot([1,2,3,4],linewidth=3.0)
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.scatter(df.MaxTemp,df.MinTemp)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0,0.5,'y')

# %%
plt.plot(df.MaxTemp,df.MinTemp,'bo','g')
plt.xlabel('Maxtemp')
plt.ylabel('Mintemp')
plt.show()

# %%
plt.boxplot(df.MinTemp )
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1fa4ece78d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1fa4ece1940>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1fa4eceeda0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1fa4eceea90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1fa4ece7908>,
#   <matplotlib.lines.Line2D at 0x1fa4ece1898>]}

# %%
sns.distplot(df['MaxTemp'],kde=True)

# %%
sns.distplot(df['MaxTemp'],hist=False,kde=True)

# %%
c=df.corr()
sns.heatmap(c)

# %%
sns.kdeplot(df.MaxTemp,bw=0.5)

# %%
sns.distplot(df['MaxTemp'],hist=False,kde=True,rug=True)

# %%
sns.jointplot(df['MaxTemp'],df['MinTemp'],kind='scatter',color= "b")

# %%
plt.figure(figsize=(15,8))
sns.kdeplot(df['MaxTemp'],df['MinTemp'])

# %%
plt.figure(figsize=(15,8))
sns.kdeplot(df['MaxTemp'],df['MinTemp'],shade=True)

# %%
plt.figure(figsize=(15,8))
sns.factorplot(x='MaxTemp',y='MinTemp',data=df)

# %%
sns.jointplot(df['MaxTemp'],df['MinTemp'],kind='kde',color= "b")

# %%
sns.lmplot(x='MaxTemp',y='MinTemp',data=df)

# %%
sns.lmplot(x='MaxTemp',y='MinTemp',data=df, hue="Rainfall")

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='MaxTemp',y='MinTemp',data=df)

# %%
plt.figure(figsize=(20,8))
sns.stripplot(x='MaxTemp',y='MinTemp',data=df)

# %%
plt.figure(figsize=(20,8))
sns.swarmplot(x='Date',y='MinTemp',data=df)

# %%
sns.barplot(x='MaxTemp',y='MinTemp',data =df)

# %%
a=sns.load_dataset('iris')

# %%
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
sns.pairplot(a)

# %%
plt.subplot(211)
plt.plot(a.sepal_length,a.sepal_width,"bo",label='a1')
plt.subplot(212)
plt.plot(a.petal_length,a.petal_width,"g",label="a2")
plt.show()
