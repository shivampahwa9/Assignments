# %%
import numpy as np

# %% [markdown]
# ## question1

# %%
a=np.random.random([10,1])

# %%
a
# Out:
# array([[0.38522147],
#        [0.1662917 ],
#        [0.51446547],
#        [0.96096761],
#        [0.35403321],
#        [0.54634468],
#        [0.53145028],
#        [0.01593332],
#        [0.66606736],
#        [0.2745835 ]])

# %%
np.mean(a)
# Out:
# 0.44607043202815744

# %% [markdown]
# ## question2

# %%
b=np.random.random([20,1])

# %%
b
# Out:
# array([[0.43301367],
#        [0.04849345],
#        [0.57158984],
#        [0.97895072],
#        [0.24913514],
#        [0.16552301],
#        [0.01207925],
#        [0.70366123],
#        [0.87564467],
#        [0.6087515 ],
#        [0.38016011],
#        [0.90757164],
#        [0.71492913],
#        [0.37609174],
#        [0.71596608],
#        [0.51151729],
#        [0.11146377],
#        [0.86294642],
#        [0.71763461],
#        [0.94503562]])

# %%
np.var(b)
# Out:
# 0.09137217690557795

# %%
np.std(b)
# Out:
# 0.30227831034590946

# %% [markdown]
# ## Question 3

# %%
m=np.random.random([10,20])

# %%
n=np.random.random([20,25])

# %%
z=np.dot(m,n)

# %%
z
# Out:
# array([[7.02967557, 6.55726948, 5.79640333, 5.52885137, 3.87868628,
#         6.3143573 , 5.42749121, 5.70617044, 6.46572697, 6.17961733,
#         5.19450664, 5.62145925, 5.87717878, 4.6436839 , 5.69699522,
#         5.9621123 , 4.93262328, 6.79155157, 6.21027692, 6.2770726 ,
#         4.5098018 , 5.23145605, 6.57952333, 5.44250228, 5.19018164],
#        [6.05453374, 5.21351513, 5.45479493, 4.47694639, 3.73613272,
#         5.17932856, 4.29968523, 4.98153989, 5.42955385, 5.60183957,
#         4.71866401, 5.1159381 , 5.12367821, 4.04428154, 5.03533354,
#         5.06114591, 4.39346693, 5.58536502, 5.25821895, 5.82638297,
#         4.11141542, 4.71116381, 5.74387804, 5.1555838 , 4.43268384],
#        [5.25202876, 6.55746199, 5.20471208, 5.64581928, 4.03188677,
#         5.56352662, 5.12934764, 4.92848808, 6.13258736, 5.3341029 ,
#         3.64041262, 4.46716896, 5.24589263, 3.55866416, 4.71048996,
#         5.18832555, 4.85964181, 6.35162257, 5.94225058, 5.6814923 ,
# ...

# %%
z.shape
# Out:
# (10, 25)

# %%
np.sum(z)
# Out:
# 1242.0247627806093

# %% [markdown]
# ## Question4

# %%
x= np.arange(10).reshape(10,1)

# %%
def myfunc(x):
    return 1/(1+np.exp(-x))

# %%
np.apply_along_axis(myfunc,0,x)
# Out:
# array([[0.5       ],
#        [0.73105858],
#        [0.88079708],
#        [0.95257413],
#        [0.98201379],
#        [0.99330715],
#        [0.99752738],
#        [0.99908895],
#        [0.99966465],
#        [0.99987661]])
